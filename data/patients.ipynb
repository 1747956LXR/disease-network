# %%
import pandas as pd 
data_path = "./mimic-iii/"
patients = pd.DataFrame(pd.read_csv(data_path + "patients.csv"))

# %%
patients.columns
# Out:
# Index(['row_id', 'subject_id', 'gender', 'dob', 'dod', 'dod_hosp', 'dod_ssn',
#        'expire_flag', 'mimic_id'],
#       dtype='object')

# %%
patients.loc[:, ["subject_id", "dob"]]
# Out:
#     subject_id                  dob
# 0        10006  2094-03-05 00:00:00
# 1        10011  2090-06-05 00:00:00
# 2        10013  2038-09-03 00:00:00
# 3        10017  2075-09-21 00:00:00
# 4        10019  2114-06-20 00:00:00
# 5        10026  1895-05-17 00:00:00
# 6        10027  2108-01-15 00:00:00
# 7        10029  2061-04-10 00:00:00
# 8        10032  2050-03-29 00:00:00
# 9        10033  2051-04-21 00:00:00
# 10       10035  2053-04-13 00:00:00
# 11       10036  1885-03-24 00:00:00
# 12       10038  2056-01-27 00:00:00
# 13       10040  2061-10-23 00:00:00
# 14       10042  2076-05-06 00:00:00
# 15       10043  2109-04-07 00:00:00
# 16       10044  2071-02-11 00:00:00
# 17       10045  2061-03-25 00:00:00
# 18       10046  2141-03-15 00:00:00
# 19       10056  2046-02-27 00:00:00
# 20       10059  2081-01-03 00:00:00
# 21       10061  2031-05-19 00:00:00
# 22       10064  2058-04-23 00:00:00
# 23       10065  2111-07-18 00:00:00
# 24       10067  2101-06-10 00:00:00
# ...
