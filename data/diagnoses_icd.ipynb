# %%
import pandas as pd 
data_path = './mimic-iii/'
diagnoses_icd = pd.DataFrame(pd.read_csv(data_path + 'diagnoses_icd.csv'))

# %%
diagnoses_icd
# Out:
#       row_id  subject_id  hadm_id  seq_num icd9_code   mimic_id
# 0     112344       10006   142345        1     99591  335981618
# 1     112345       10006   142345        2     99662  335981619
# 2     112346       10006   142345        3      5672  335981620
# 3     112347       10006   142345        4     40391  335981621
# 4     112348       10006   142345        5     42731  335981622
# 5     112349       10006   142345        6      4280  335981623
# 6     112350       10006   142345        7      4241  335981624
# 7     112351       10006   142345        8      4240  335981625
# 8     112352       10006   142345        9      2874  335981626
# 9     112353       10006   142345       10     03819  335981627
# 10    112354       10006   142345       11      7850  335981628
# 11    112355       10006   142345       12     E8791  335981629
# 12    112356       10006   142345       13      V090  335981630
# 13    112357       10006   142345       14     56211  335981631
# ...
